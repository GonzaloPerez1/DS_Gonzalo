# %%
a7 = ['client_id', 'id_suscripcion', 'ant_suscripcion',
 'video_0', 'video_100', 'video_25',
 'video_50', 'video_75', 'pct_views_category_series',
 'pct_views_category_telenovelas', 'pct_views_category_programas', 'pct_views_category_noticias',
 'pct_views_category_snacks', 'pct_views_category_deportes', 'pct_views_category_documentales',
 'pct_views_category_infantil', 'pct_views_category_otros', 'num_days_active',
 'num_views_total', 'time_viewed_vod', 'time_viewed_total',
 'num_views_category_deportes', 'num_views_category_documentales', 'num_views_category_otros',
 'num_views_category_programas', 'num_views_category_series', 'num_views_category_snacks',
 'num_views_category_telenovelas', 'num_views_category_noticias', 'num_views_category_infantil',
 'pct_rel_conexion_device_mobile', 'pct_rel_conexion_device_tablet', 'pct_rel_conexion_device_television',
 'pct_rel_conexion_device_pc', 'pct_rel_conexion_device_other', 'pct_rel_conexion_platform_web',
 'pct_rel_conexion_platform_app', 'pct_rel_conexion_platform_tv', 'pct_rel_conexion_platform_other',
 'ant_registro', 'registrado_to_suscriptor', 'num_views_category_total',
 'num_days_active_month_-1', 'num_views_total_-1', 'time_viewed_total_-1',
 'video_0_-1', 'video_25_-1', 'video_50_-1',
 'video_75_-1', 'video_100_-1', 'num_views_category_series_-1',
 'num_views_category_telenovelas_-1', 'num_views_category_programas_-1', 'num_views_category_noticias_-1',
 'num_views_category_snacks_-1', 'num_views_category_deportes_-1', 'num_views_category_documentales_-1',
 'num_views_category_otros_-1', 'num_views_category_total_-1', 'pct_views_category_series_-1',
 'pct_views_category_telenovelas_-1', 'pct_views_category_programas_-1', 'pct_views_category_noticias_-1',
 'pct_views_category_snacks_-1', 'pct_views_category_deportes_-1', 'pct_views_category_documentales_-1',
 'pct_views_category_otros_-1', 'num_days_active_month_-2', 'num_views_total_-2',
 'time_viewed_total_-2', 'video_0_-2', 'video_25_-2',
 'video_50_-2', 'video_75_-2', 'video_100_-2',
 'num_views_category_series_-2', 'num_views_category_telenovelas_-2', 'num_views_category_programas_-2',
 'num_views_category_noticias_-2', 'num_views_category_snacks_-2', 'num_views_category_deportes_-2',
 'num_views_category_documentales_-2', 'num_views_category_otros_-2', 'num_views_category_total_-2',
 'pct_views_category_series_-2', 'pct_views_category_telenovelas_-2', 'pct_views_category_programas_-2',
 'pct_views_category_noticias_-2', 'pct_views_category_snacks_-2', 'pct_views_category_deportes_-2',
 'pct_views_category_documentales_-2', 'pct_views_category_otros_-2', 'num_days_active_month_-3',
 'num_views_total_-3', 'time_viewed_total_-3', 'video_0_-3',
 'video_25_-3', 'video_50_-3', 'video_75_-3',
 'video_100_-3', 'num_views_category_series_-3', 'num_views_category_telenovelas_-3',
 'num_views_category_programas_-3', 'num_views_category_noticias_-3', 'num_views_category_snacks_-3',
 'num_views_category_deportes_-3', 'num_views_category_documentales_-3', 'num_views_category_otros_-3',
 'num_views_category_total_-3', 'pct_views_category_series_-3', 'pct_views_category_telenovelas_-3',
 'pct_views_category_programas_-3', 'pct_views_category_noticias_-3', 'pct_views_category_snacks_-3',
 'pct_views_category_deportes_-3', 'pct_views_category_documentales_-3', 'pct_views_category_otros_-3',
 'num_days_active_trend', 'num_views_trend', 'time_viewed_total_trend',
 'video_0_trend', 'video_25_trend', 'video_50_trend',
 'video_75_trend', 'video_100_trend', 'tipo_oferta_Año gratis Nacional',
 'tipo_oferta_Campaña Navidad Huawei 6 meses ', 'tipo_oferta_Códigos Mahou - FOQ', 'tipo_oferta_Códigos Tester Vodafone 1 año',
 'tipo_oferta_Códigos actores FOQ', 'tipo_oferta_Códigos aperitivos la real', 'tipo_oferta_Códigos compensación',
 'tipo_oferta_Códigos prensa Fiesta Veneno', 'tipo_oferta_Premium Nacional - 7 días gratis', 'tipo_oferta_Premium Nacional con pago anual',
 'tipo_oferta_Roscones El Corte Inglés', 'tipo_oferta_Segundo Año Gratis Prensa', 'tipo_oferta_TD Systems 1 mes gratis Premium',
 'tipo_oferta_Tres meses gratis Premium Nacional', 'tipo_oferta_códigos compromisos', 'tipo_oferta_deconocido',
 'tipo_pago_CARD', 'tipo_pago_MOVISTAR_LEGACY', 'tipo_pago_PAYPAL',
 'tipo_pago_PAYPAL_LEGACY', 'tipo_pago_VODAFONE_PPE', 'tipo_pago_deconocido',
 's01_conexion_movil_1.0', 's02_conexion_television_1.0', 's03_conexion_tablet_1.0',
 's04_conexion_pc_1.0', 's05_paracaidistas_de_redes_sociales_1.0', 's06_paracaidistas_externos_1.0',
 's07_asiduo_flooxer_adolescence_1.0', 's08_asiduo_flooxer_mediaedad_1.0', 's09_asiduo_actualidad_1.0',
 's10_asiduo_seriesytelenovelas_1.0', 's11_asiduo_deportes_1.0', 's12_asiduo_noticias_externas_1.0',
 's13_asiduo_series_en_maraton_1.0', 's14_asiduo_series_en_emision_1.0', 's15_asiduo_internacional_expatriado_1.0',
 's16_asiduo_internacional_telenovela_1.0', 's17_solo_un_contenido_consumido_1.0', 's18_sin_consumo_1.0',
 's00_sin_segmento_asignado_1.0', 'rango_edad_24-33', 'rango_edad_34-49',
 'rango_edad_50-63', 'rango_edad_63+', 'rango_edad_No declarado',
 'rango_suscripcion_02-04_meses', 'rango_suscripcion_05-07_meses', 'rango_suscripcion_08-10_meses',
 'rango_suscripcion_11-12_meses', 'rango_suscripcion_12+_meses', 'rango_registro_to_suscriptor_0-1_mes',
 'rango_registro_to_suscriptor_2-3_meses', 'rango_registro_to_suscriptor_4-5_meses', 'rango_registro_to_suscriptor_6-7_meses',
 'rango_registro_to_suscriptor_7+_meses']







a8 = ['client_id', 'id_suscripcion', 's07_asiduo_flooxer_adolescence_1.0',
 'rango_edad_50-63', 'pct_rel_conexion_platform_other', 'pct_views_category_deportes_-2',
 's06_paracaidistas_externos_1.0', 'time_viewed_total', 'rango_edad_34-49',
 'tipo_pago_PAYPAL_LEGACY', 'pct_views_category_programas', 'ant_suscripcion',
 'num_views_total_-1', 'video_50_-1', 'rango_edad_24-33',
 'video_75_-3', 'num_views_category_snacks_-3', 'pct_views_category_programas_-1',
 'num_views_category_otros_-3', 'video_100_trend', 'video_75_-1',
 'num_views_category_deportes_-1', 'num_views_category_documentales', 'pct_views_category_series_-1',
 'pct_views_category_documentales_-3', 'pct_views_category_telenovelas_-3', 'pct_views_category_otros_-3',
 'video_0_-3', 's01_conexion_movil_1.0', 's03_conexion_tablet_1.0',
 'num_views_category_otros_-1', 'video_100_-3', 'pct_views_category_telenovelas_-2',
 'video_25_-1', 'video_25', 'pct_views_category_documentales_-1',
 's04_conexion_pc_1.0', 'tipo_oferta_deconocido', 'num_days_active_trend',
 'num_views_total_-2', 'pct_views_category_series_-3', 'time_viewed_total_trend',
 'num_views_category_programas_-1', 'tipo_oferta_Códigos Tester Vodafone 1 año', 'num_views_category_series_-1',
 'pct_views_category_series_-2', 'rango_suscripcion_02-04_meses', 'tipo_pago_PAYPAL',
 'num_views_category_series', 'video_0_-2', 'num_views_category_total_-3',
 's05_paracaidistas_de_redes_sociales_1.0', 'video_25_trend', 's18_sin_consumo_1.0',
 'num_views_category_noticias_-3', 'rango_suscripcion_11-12_meses', 'num_views_category_deportes',
 'video_0_trend', 's00_sin_segmento_asignado_1.0', 'num_views_category_total_-1',
 'video_0_-1', 'pct_rel_conexion_platform_web', 'num_views_category_total_-2',
 'rango_registro_to_suscriptor_7+_meses', 'rango_registro_to_suscriptor_0-1_mes', 'num_views_category_noticias',
 'num_views_category_telenovelas_-1', 'num_days_active_month_-1', 'num_views_category_documentales_-2',
 'video_50_-2', 'num_views_trend', 'num_views_category_series_-3',
 'rango_suscripcion_08-10_meses', 'num_views_category_noticias_-2', 'tipo_oferta_Códigos prensa Fiesta Veneno',
 'tipo_pago_CARD', 'tipo_pago_MOVISTAR_LEGACY', 'tipo_oferta_Premium Nacional - 7 días gratis',
 'pct_views_category_otros', 'pct_views_category_programas_-3', 'video_75_trend',
 'num_views_category_programas_-2', 's08_asiduo_flooxer_mediaedad_1.0', 'pct_views_category_noticias',
 'video_0', 'pct_rel_conexion_device_tablet', 'pct_views_category_deportes_-1',
 'pct_views_category_snacks', 'pct_views_category_documentales', 'video_50_trend',
 's14_asiduo_series_en_emision_1.0', 'video_50', 'num_views_category_total',
 'rango_suscripcion_12+_meses', 'num_days_active_month_-3', 'num_views_category_documentales_-1',
 's13_asiduo_series_en_maraton_1.0', 'pct_views_category_telenovelas', 'num_views_category_noticias_-1',
 'rango_suscripcion_05-07_meses', 'pct_views_category_series', 'pct_rel_conexion_device_television',
 'tipo_oferta_Tres meses gratis Premium Nacional', 'pct_views_category_noticias_-2', 'time_viewed_total_-1',
 'pct_views_category_noticias_-1', 'pct_rel_conexion_platform_tv', 'time_viewed_vod',
 'num_views_category_series_-2', 'rango_edad_63+', 'num_views_category_snacks_-1',
 'registrado_to_suscriptor', 'tipo_oferta_Premium Nacional con pago anual', 'pct_views_category_snacks_-1',
 'video_50_-3', 'num_views_category_deportes_-3', 'pct_rel_conexion_device_pc',
 's12_asiduo_noticias_externas_1.0', 'tipo_pago_deconocido', 'video_25_-2',
 'pct_views_category_otros_-1', 'video_25_-3', 's16_asiduo_internacional_telenovela_1.0',
 'pct_views_category_deportes_-3', 'num_views_category_deportes_-2', 'pct_views_category_programas_-2',
 'time_viewed_total_-2', 'tipo_oferta_Segundo Año Gratis Prensa', 'video_75',
 'time_viewed_total_-3', 'num_views_total_-3', 'num_views_category_documentales_-3',
 's09_asiduo_actualidad_1.0', 'video_100', 'tipo_oferta_Códigos compensación',
 'num_days_active', 'num_views_category_programas', 'tipo_oferta_Año gratis Nacional',
 'pct_rel_conexion_platform_app', 'num_days_active_month_-2', 'num_views_category_telenovelas_-3',
 's10_asiduo_seriesytelenovelas_1.0', 'video_100_-1', 'pct_views_category_deportes',
 's15_asiduo_internacional_expatriado_1.0', 'pct_views_category_documentales_-2', 'num_views_category_snacks_-2',
 's02_conexion_television_1.0', 'num_views_category_telenovelas_-2', 'video_100_-2',
 'ant_registro', 'rango_registro_to_suscriptor_4-5_meses', 'tipo_oferta_códigos compromisos',
 'num_views_category_telenovelas', 'pct_views_category_telenovelas_-1', 'num_views_category_snacks',
 'pct_views_category_snacks_-2', 'tipo_oferta_Roscones El Corte Inglés', 'num_views_category_otros_-2',
 'pct_views_category_snacks_-3', 'video_75_-2', 'rango_registro_to_suscriptor_6-7_meses',
 'pct_views_category_otros_-2', 'pct_views_category_noticias_-3', 's11_asiduo_deportes_1.0',
 'rango_registro_to_suscriptor_2-3_meses', 's17_solo_un_contenido_consumido_1.0', 'pct_rel_conexion_device_mobile',
 'num_views_category_programas_-3', 'num_views_category_otros', 'pct_rel_conexion_device_other',
 'num_views_total', 'rango_edad_No declarado']

# %%
sa7 = set(a7)
sa8 = set(a8)

# %%
sa8.difference(sa7)
# Out:
# set()
