# %% [markdown]
# ## Proyecto EDA
#
# # Datos:
#
# Los datos los he recogido de Kaggle, el dataset muestra las cantidad de muertes por diferentes causas,
# dichos datos han sido recogidos de la OMS [datos](https://www.kaggle.com/varpit94/worldwide-deaths-by-risk-factors "datos")
# En este dataset hay 6468 filas y 31 columnas.
#
# Las columnas son:
#    1. **Entity**: País.
#    2. **Year**: Año.
#    3. **Unsafe water source**: Fuente de agua insegura.
#    4. **Unsafe sanitatio**: Saneamiento inseguro.
#    5. **No access to handwashing facility**: Sin acceso para lavarse las manos.
#    6. **Non-exclusive breastfeeding**: Lactancia materna no exclusiva.
#    7. **Discontinued breastfeeding**: Lactancia discontinua.
#    8. **Child wasting**: Emaciación infantil (pérdida involuntaria de peso corporal).
#    9. **Child stunting**: Retraso del crecimiento infantil.
#    10. **Low birth weight for gestation**: Peso bajo al nacer por problemas en la gestación..
#    11. **Secondhand smoke**: Fumadores pasivos.
#    12. **Alcohol use**: Ingesta de alcohol.
#    13. **Drug use**: Consumo de drogas.
#    14. **Diet low in fruits**: Dieta baja en fruta.
#    15. **Diet low in vegetables**: Dieta baja en verduras.
#    16. **Unsafe sex**: Sexo inseguro.
#    17. **Low physical activity**: Poca actividad física.
#    18. **High fasting plasma glucose**: Glucosa plasmática, en ayunas, alta (mide la glucosa en sangre).
#    19. **High total cholesterol**: Colesterol alto.
#    20. **High body-mass index**: Índice de masa corporal alto.
#    21. **High systolic blood pressure**: Presión arterial alta.
#    22. **Smoking**: Consumo de tabaco.
#    23. **Iron deficiency**: Anemia (deficiencia de hierro en sangre).
#    24. **Vitamin A deficiency**: Deficiencia de vitamina A.
#    25. **Low bone mineral density**: Densidad ósea baja.
#    26. **Air pollution**: Contaminación del aire.
#    27. **Outdoor air pollution**: Contaminación del aire en exteriores.
#    28. **Diet high in sodium**: Dietas altas en sodio.
#    29. **Diet low in whole grains**: Dieta baja en cereales integrales.
#    30. **Diet low in nuts and seeds**: Dieta baja en frutos secos y semillas.
#
# Excepto en algunas columnas, el dataset carece de nulos

# %% [markdown]
# # 1.Importamos las librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Importamos los datos

# %%
df = pd.read_csv('./data/number-of-deaths-by-risk-factor.csv', sep=',')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-795fe9ad8b3f> in <module>
# ----> 1 df = pd.read_csv('./data/number-of-deaths-by-risk-factor.csv', sep=',')
#       2 df.head()
#
# ...

# %% [markdown]
# # 3.Comprobamos cuantas filas y cuantas columnas tiene

# %%
print('Tiene', df.shape[0], 'filas.')
print('Tiene', df.shape[1], 'columnas.')
# Out:
# Tiene 6468 filas.
# Tiene 31 columnas.

# %% [markdown]
# # 4.Comprobamos si el dataset contiene nulos y que tipo de datos tenemos

# %% [markdown]
# Podemos ver que excepto el nombre del país y el año el resto de datos son float64. También podemos ver que en las columnas
# **'High total cholesterol'** y **'Outdoor air pollution'** tenemos valores nulos (NaN).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 31 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Entity                                    6468 non-null   object
#  1   Year                                      6468 non-null   int64
#  2   Unsafe water source                       6468 non-null   float64
#  3   Unsafe sanitation                         6468 non-null   float64
#  4   No access to handwashing facility         6468 non-null   float64
#  5   Household air pollution from solid fuels  6468 non-null   float64
#  6   Non-exclusive breastfeeding               6468 non-null   float64
#  7   Discontinued breastfeeding                6468 non-null   float64
#  8   Child wasting                             6468 non-null   float64
#  9   Child stunting                            6468 non-null   float64
# ...

# %% [markdown]
# # 5.Gráficas

# %% [markdown]
# Comprobamos la **correlación** de los datos

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), 
            vmin = -1, 
            vmax = 1,
            cmap=sns.diverging_palette(150, 277, s=100, l=30, n=13),
            annot = True);

# %%
df.corr()
# Out:
#                                               Year  Unsafe water source  \
# Year                                      1.000000            -0.033763
# Unsafe water source                      -0.033763             1.000000
# Unsafe sanitation                        -0.043005             0.998419
# No access to handwashing facility        -0.034788             0.995187
# Household air pollution from solid fuels -0.036266             0.912757
# Non-exclusive breastfeeding              -0.071945             0.964772
# Discontinued breastfeeding               -0.073736             0.935980
# Child wasting                            -0.070183             0.966443
# Child stunting                           -0.082384             0.958057
# Low birth weight for gestation           -0.037519             0.974936
# Secondhand smoke                         -0.007547             0.740803
# Alcohol use                               0.029528             0.745933
# ...

# %%
x1 = df['Unsafe water source']
x2 = df['Unsafe sanitation']

plt.figure(figsize=(10,8))
plt.scatter(x1,x2);

# %%
plt.hist(x1, bins=40);

# %%
df_2 = df[df['Entity'] == 'Spain']
df_2.sort_values(by='Year') #Dataframe final
# Out:
#      Entity  Year  Unsafe water source  Unsafe sanitation  \
# 5404  Spain  1990            13.242128          12.079771
# 5405  Spain  1991            12.675227          11.011922
# 5406  Spain  1992            12.193780          10.041955
# 5407  Spain  1993            12.385512           9.707817
# 5408  Spain  1994            12.867121           9.640057
# 5409  Spain  1995            13.460639           9.677911
# 5410  Spain  1996            13.763778           9.542582
# 5411  Spain  1997            14.171398           9.487223
# 5412  Spain  1998            15.544976          10.054884
# 5413  Spain  1999            17.258183          10.794554
# 5414  Spain  2000            18.609746          11.240033
# 5415  Spain  2001            19.993134          11.640385
# 5416  Spain  2002            21.843811           9.910789
# 5417  Spain  2003            23.912309          10.438051
# 5418  Spain  2004            24.737483          10.351631
# ...

# %%
x = sorted(df_2.groupby('Entity').sum())
print(x)
x1 = x[:11]
df_3 = df[x1]
df_3
# Out:
# ['Air pollution', 'Alcohol use', 'Child stunting', 'Child wasting', 'Diet high in sodium', 'Diet low in fruits', 'Diet low in nuts and seeds', 'Diet low in vegetables', 'Diet low in whole grains', 'Discontinued breastfeeding', 'Drug use', 'High body-mass index', 'High fasting plasma glucose', 'High systolic blood pressure', 'High total cholesterol', 'Household air pollution from solid fuels', 'Iron deficiency', 'Low birth weight for gestation', 'Low bone mineral density', 'Low physical activity', 'No access to handwashing facility', 'Non-exclusive breastfeeding', 'Outdoor air pollution', 'Secondhand smoke', 'Smoking', 'Unsafe sanitation', 'Unsafe sex', 'Unsafe water source', 'Vitamin A deficiency', 'Year']
#       Air pollution  Alcohol use  Child stunting  Child wasting  \
# 0      26598.006730   356.529307    10408.438850   22778.849250
# 1      26379.532220   320.598461    10271.976430   22292.691110
# 2      27263.127910   293.257016    10618.879780   23102.197940
# ...

# %%
plt.figure(figsize=(10,10))
sns.histplot(df_3['Air pollution'], kde=True);

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df_3['Air pollution'], df_3['Alcohol use'])
# Out:
# /home/gonzalo/Documentos/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Air pollution', ylabel='Alcohol use'>

# %% [markdown]
# ## Datos nuevos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/Catalogo_de_Hospitales.csv')
df.head()
# Out:
#    Código CCN  Código CNH                                Nombre  \
# 0   104000314       40059               HOSPITAL VIRGEN DEL MAR
# 1   104000316       40010  HOSPITAL UNIVERSITARIO TORRECARDENAS
# 2   104000319       40031  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA
# 3   104000320       40084                HOSPITAL LA INMACULADA
# 4   104000321       40118                  HOSPITAL DE PONIENTE
#
#   Comunidad Autónoma Provincia      Municipio                       Dirección  \
# 0          ANDALUCÍA   ALMERÍA        Almería   CARRETERA DEL MAMI, KM. 1 S/N
# 1          ANDALUCÍA   ALMERÍA        Almería  CALLE PARAJE TORRECARDENAS S/N
# 2          ANDALUCÍA   ALMERÍA        Almería          CARRETERA DE RONDA S/N
# 3          ANDALUCÍA   ALMERÍA  Huércal-Overa   AVENIDA DOCTORA ANA PARRA S/N
# 4          ANDALUCÍA   ALMERÍA      Ejido, El         CARRETERA ALMERIMAR S/N
#
#    Código Postal   Teléfono  Número de camas instaladas        Tipo de Centro  \
# ...

# %%
df.shape
# Out:
# (831, 15)

# %%
df['Número de camas instaladas'].sum()
# Out:
# 158648

# %%
sorted(df['Provincia'].unique())
# Out:
# ['A CORUÑA',
#  'ALBACETE',
#  'ALICANTE',
#  'ALMERÍA',
#  'ASTURIAS',
#  'BADAJOZ',
#  'BARCELONA',
#  'BURGOS',
#  'CANTABRIA',
#  'CASTELLÓN',
#  'CEUTA',
#  'CIUDAD REAL',
#  'CUENCA',
#  'CÁCERES',
#  'CÁDIZ',
#  'CÓRDOBA',
#  'GIRONA',
#  'GRANADA',
#  'GUADALAJARA',
#  'GUIPÚZCOA',
#  'HUELVA',
#  'HUESCA',
#  'ILLES BALEARS',
#  'JAÉN',
#  'LA RIOJA',
#  'LAS PALMAS',
#  'LEÓN',
#  'LLEIDA',
#  'LUGO',
#  'MADRID',
#  'MALAGA',
#  'MELILLA',
#  'MURCIA',
#  'NAVARRA',
#  'OURENSE',
#  'PALENCIA',
#  'PONTEVEDRA',
#  'SALAMANCA',
#  'SANTA CRUZ DE TENERIFE',
#  'SEGOVIA',
#  'SEVILLA',
#  'SORIA',
#  'TARRAGONA',
#  'TERUEL',
#  'TOLEDO',
#  'VALENCIA',
#  'VALLADOLID',
#  'VIZCAYA',
#  'ZAMORA',
#  'ZARAGOZA',
#  'ÁLAVA',
#  'ÁVILA']

# %%
sorted(df['Municipio'].unique())
# Out:
# ['Adeje',
#  'Albacete',
#  'Albelda de Iregua',
#  'Alcalá de Guadaíra',
#  'Alcalá de Henares',
#  'Alcalá la Real',
#  'Alcantarilla',
#  'Alcaudete',
#  'Alcañiz',
#  'Alcorcón',
#  'Alcoy/Alcoi',
#  'Alcázar de San Juan',
#  'Alella',
#  'Algeciras',
#  'Alicante/Alacant',
#  'Almacelles',
#  'Almansa',
#  'Almendralejo',
#  'Almería',
#  'Alpicat',
#  'Altsasu/Alsasua',
#  'Alzira',
#  "Ametlla del Vallès, L'",
#  'Amposta',
#  'Andújar',
#  'Antequera',
#  'Aranda de Duero',
#  'Aranjuez',
#  'Arenys de Munt',
#  'Arganda del Rey',
#  'Argentona',
#  'Arona',
#  'Arrasate/Mondragón',
#  'Arrecife',
#  'Arévalo',
#  'Avilés',
#  'Badajoz',
#  'Badalona',
#  'Balaguer',
#  'Banyoles',
#  'Barakaldo',
#  'Barbastro',
#  'Barcelona',
#  'Barco de Valdeorras, O',
#  'Barrios, Los',
#  'Baza',
#  'Baztan',
#  'Benalmádena',
#  'Benavente',
#  'Benidorm',
#  'Berga',
#  'Bermeo',
#  'Bilbao',
#  'Blanes',
#  'Boadilla del Monte',
#  'Bormujos',
#  'Breña Alta',
#  'Brunete',
# ...

# %%
df[df['Nombre'] == 'HOSPITAL UNIVERSITARIO INFANTA LEONOR']
# Out:
#      Código CCN  Código CNH                                 Nombre  \
# 725  1328000086      281270  HOSPITAL UNIVERSITARIO INFANTA LEONOR
#
#     Comunidad Autónoma Provincia Municipio  \
# 725             MADRID    MADRID    Madrid
#
#                               Dirección  Código Postal   Teléfono  \
# 725  AVENIDA DE LA GRAN VIA DEL ESTE 80          28031  911918000
#
#      Número de camas instaladas        Tipo de Centro  \
# 725                         269  Hospitales Generales
#
#                                  Dependencia Funcional  Observaciones  \
# 725  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
#
#           Concierto Acreditación Docente
# 725  Sin concierto.                   NO

# %%
df['Dirección'].nunique()
# Out:
# 820

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),
           vmin = -1,
           vmax = 1,
           annot = True,
           square = True,
           linewidth = .5,
           cmap=sns.diverging_palette(150, 277, s=100, l=30, n=13));

# %%
df.corr()
# Out:
#                             Código CCN  Código CNH  Código Postal  \
# Código CCN                    1.000000    0.009337       0.009445
# Código CNH                    0.009337    1.000000       0.999771
# Código Postal                 0.009445    0.999771       1.000000
# Número de camas instaladas    0.073172    0.017410       0.016002
# Observaciones                      NaN         NaN            NaN
#
#                             Número de camas instaladas  Observaciones
# Código CCN                                    0.073172            NaN
# Código CNH                                    0.017410            NaN
# Código Postal                                 0.016002            NaN
# Número de camas instaladas                    1.000000            NaN
# Observaciones                                      NaN            NaN

# %%
plt.figure(figsize=(12,12))
sns.histplot(data = df,
        x = 'Número de camas instaladas',
        multiple = 'stack',
        hue = 'Dependencia Funcional',
        palette='dark',
        edgecolor="0.1",
        linewidth=.7);

# %%
data = df.groupby('Nombre')['Número de camas instaladas'].sum()
data = pd.DataFrame(data)
mas_camas = data.sort_values(by='Número de camas instaladas', ascending= False)
mas_camas = mas_camas[:11]
mas_camas
# Out:
#                                                     Número de camas instaladas
# Nombre
# COMPLEXO HOSPITALARIO UNIVERSITARIO DE SANTIAGO                           1395
# COMPLEXO HOSPITALARIO UNIVERSITARIO A CORUÑA                              1341
# HOSPITAL UNIVERSITARI VALL D'HEBRON                                       1315
# COMPLEXO HOSPITALARIO UNIVERSITARIO DE VIGO                               1273
# HOSPITAL GENERAL UNIVERSITARIO GREGORIO MARAÑON                           1253
# HOSPITAL UNIVERSITARIO MIGUEL SERVET                                      1213
# HOSPITAL UNIVERSITARIO 12 DE OCTUBRE                                      1196
# COMPLEJO HOSPITALARIO DE NAVARRA                                          1077
# PARC SANITARI SANT JOAN DE DEU - RECINTE SANT BOI.                        1065
# HOSPITAL UNIVERSITARIO LA PAZ                                             1052
# HOSPITAL UNIVERSITARIO DONOSTIA                                           1034

# %%
plt.figure(figsize=(10,5))
plt.hlines(y=mas_camas['Número de camas instaladas'].index,
           xmin=0,
           xmax=mas_camas['Número de camas instaladas'],
           color='#A300F5')
plt.plot(mas_camas['Número de camas instaladas'], mas_camas['Número de camas instaladas'].index, "o", color='#A300F5')
plt.xlabel('Número de camas');

# %%
data = df.groupby(['Nombre', 'Comunidad Autónoma'])['Número de camas instaladas'].sum()
data = pd.DataFrame(data)
mas_camas = data.sort_values(by='Número de camas instaladas', ascending= False)
mas_camas = mas_camas[:11]
mas_camas.reset_index(inplace=True)
mas_camas['Posicion'] = range(1,12)
mas_camas
# Out:
#                                                Nombre   Comunidad Autónoma  \
# 0     COMPLEXO HOSPITALARIO UNIVERSITARIO DE SANTIAGO              GALICIA
# 1        COMPLEXO HOSPITALARIO UNIVERSITARIO A CORUÑA              GALICIA
# 2                 HOSPITAL UNIVERSITARI VALL D'HEBRON             CATALUÑA
# 3         COMPLEXO HOSPITALARIO UNIVERSITARIO DE VIGO              GALICIA
# 4     HOSPITAL GENERAL UNIVERSITARIO GREGORIO MARAÑON               MADRID
# 5                HOSPITAL UNIVERSITARIO MIGUEL SERVET               ARAGÓN
# 6                HOSPITAL UNIVERSITARIO 12 DE OCTUBRE               MADRID
# 7                    COMPLEJO HOSPITALARIO DE NAVARRA  C. FORAL DE NAVARRA
# 8   PARC SANITARI SANT JOAN DE DEU - RECINTE SANT ...             CATALUÑA
# 9                       HOSPITAL UNIVERSITARIO LA PAZ               MADRID
# 10                    HOSPITAL UNIVERSITARIO DONOSTIA           PAÍS VASCO
#
#     Número de camas instaladas  Posicion
# ...

# %%
data = df.groupby(['Nombre', 'Comunidad Autónoma'])['Número de camas instaladas'].sum()
data = pd.DataFrame(data)
mas_camas = data.sort_values(by='Número de camas instaladas', ascending= False)
mas_camas = mas_camas[:11]
mas_camas.reset_index(inplace=True)
mas_camas
# Out:
#                                                Nombre   Comunidad Autónoma  \
# 0     COMPLEXO HOSPITALARIO UNIVERSITARIO DE SANTIAGO              GALICIA
# 1        COMPLEXO HOSPITALARIO UNIVERSITARIO A CORUÑA              GALICIA
# 2                 HOSPITAL UNIVERSITARI VALL D'HEBRON             CATALUÑA
# 3         COMPLEXO HOSPITALARIO UNIVERSITARIO DE VIGO              GALICIA
# 4     HOSPITAL GENERAL UNIVERSITARIO GREGORIO MARAÑON               MADRID
# 5                HOSPITAL UNIVERSITARIO MIGUEL SERVET               ARAGÓN
# 6                HOSPITAL UNIVERSITARIO 12 DE OCTUBRE               MADRID
# 7                    COMPLEJO HOSPITALARIO DE NAVARRA  C. FORAL DE NAVARRA
# 8   PARC SANITARI SANT JOAN DE DEU - RECINTE SANT ...             CATALUÑA
# 9                       HOSPITAL UNIVERSITARIO LA PAZ               MADRID
# 10                    HOSPITAL UNIVERSITARIO DONOSTIA           PAÍS VASCO
#
#     Número de camas instaladas
# 0                         1395
# ...

# %%
data = df.groupby(['Nombre', 'Dirección'])['Número de camas instaladas'].sum()
data = pd.DataFrame(data)
mas_camas = data.sort_values(by='Número de camas instaladas', ascending= False)
mas_camas = mas_camas[:11]
mas_camas.reset_index(inplace=True)
mas_camas
# Out:
#                                                Nombre  \
# 0     COMPLEXO HOSPITALARIO UNIVERSITARIO DE SANTIAGO
# 1        COMPLEXO HOSPITALARIO UNIVERSITARIO A CORUÑA
# 2                 HOSPITAL UNIVERSITARI VALL D'HEBRON
# 3         COMPLEXO HOSPITALARIO UNIVERSITARIO DE VIGO
# 4     HOSPITAL GENERAL UNIVERSITARIO GREGORIO MARAÑON
# 5                HOSPITAL UNIVERSITARIO MIGUEL SERVET
# 6                HOSPITAL UNIVERSITARIO 12 DE OCTUBRE
# 7                    COMPLEJO HOSPITALARIO DE NAVARRA
# 8   PARC SANITARI SANT JOAN DE DEU - RECINTE SANT ...
# 9                       HOSPITAL UNIVERSITARIO LA PAZ
# 10                    HOSPITAL UNIVERSITARIO DONOSTIA
#
#                             Dirección  Número de camas instaladas
# 0             CALLE CHOUPANA (DA) S/N                        1395
# 1           LUGAR JUBIAS DE ARRIBA 84                        1341
# 2         PASEO VALL D'HEBRON 119-129                        1315
# ...

# %%
import folium # pip install folium
from folium import plugins
import ipywidgets
import geocoder # pip install geocoder
import geopy # pip install geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds # pip install vega_datasets

lista_sitios = []
for i in mas_camas['Nombre']:
    g = geocoder.osm(i)
    lista_sitios.append(g.latlng)
    
lista_sitios
# Out:
# [[42.86988465, -8.56585229973772],
#  [43.34426335, -8.38914622033265],
#  None,
#  None,
#  [40.419688449999995, -3.6711262290170836],
#  [41.63455725, -0.8997979456424298],
#  [40.376679499999995, -3.6988633268413382],
#  [42.805091399999995, -1.6685624933271659],
#  None,
#  [40.48144225, -3.6872531870474865],
#  None]

# %%
lista_sitios[2] = geocoder.osm('HOSPITAL GENERAL VALL D\'HEBRON').latlng
lista_sitios[3] = geocoder.osm('HOSPITAL ÁLVARO CUNQUEIRO').latlng
lista_sitios[8] = geocoder.osm('PARC SANITARI SANT JOAN DE DÉU').latlng
lista_sitios[10] = geocoder.osm('DONOSTIA UNIBERTSITATE OSPITALEA').latlng
lista_sitios
# Out:
# [[42.86988465, -8.56585229973772],
#  [43.34426335, -8.38914622033265],
#  [41.4277848, 2.141776007090297],
#  [42.1887328, -8.712989051162797],
#  [40.419688449999995, -3.6711262290170836],
#  [41.63455725, -0.8997979456424298],
#  [40.376679499999995, -3.6988633268413382],
#  [42.805091399999995, -1.6685624933271659],
#  [41.352797300000006, 2.0338930049315387],
#  [40.48144225, -3.6872531870474865],
#  [43.29256885, -1.9688987610446949]]

# %%
import folium
map_cities = folium.Map(location=[40, -2], zoom_start=6)

for i in range(len(lista_sitios)):
    folium.Marker(location=lista_sitios[i]).add_to(map_cities)
    
map_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(y = mas_camas['Número de camas instaladas'],
            x = mas_camas['Posicion'],
            hue = mas_camas['Comunidad Autónoma'],
            sizes = (20,200),
            palette = 'deep');

# %%
plt.figure(figsize=(8,8))
sns.histplot(data = mas_camas,
        x = 'Comunidad Autónoma',
        multiple = 'stack',
        hue = 'Posicion',
        palette='dark',
        edgecolor="0.1",
        linewidth=.7)
plt.xticks(rotation=60);

# %% [markdown]
# ## Datos Equipo médico
# - **TAC**:Tomografía Axial Computerizada
# - **RM**: Resonancia Magnética
# - **GAM**: Gammacámara
# - **HEM**: Sala de Hemodinámica
# - **ASD**: Angiografía por Sustracción Digital
# - **LIT**: Litotricia Extracorporea por Ondas de Choque
# - **BCO**: Bomba de Cobalto
# - **ALI**: Acelerador de Partículas
# - **SPECT**: Tomografía por emisión de fotones
# - **PET**: Tomografía por emisión de positrones
# - **MAMOS**: Mamógrafo
# - **DO**: Densitómetros Óseos
# - **DIAL**: Equipos de Hemodiálisis
# - Cataluña: Los datos de gammacámara incluyen SPECT

# %%
import pandas as pd

em = pd.read_csv('./data/Equipo_Médico.csv', sep='\t')
d = df.groupby('Comunidad Autónoma')['Número de camas instaladas'].sum()
df_suelto = pd.DataFrame(d)
df_2 = df_suelto.merge(em, on='Comunidad Autónoma', how='inner')
df_2.head()
# Out:
#     Comunidad Autónoma  Número de camas instaladas  TAC  RM  GAM  HEM  ASD  \
# 0            ANDALUCÍA                       21350  143  77   31   53   44
# 1               ARAGÓN                        5290   24  23    1    8    7
# 2  C. FORAL DE NAVARRA                        2331   15  10    0    3    2
# 3             CANARIAS                        6828   38  32   13   14   17
# 4            CANTABRIA                        1682    9   6    0    2    4
#
#    LIT  BCO  ALI  SPECT  PET  MAMOS  DO  DIAL
# 0   15    0   37     12    8     91  38   689
# 1    3    0    6      4    2     23   4   231
# 2    2    0    6      4    2      8   3   111
# 3    7    0   14     13    3     30  15   332
# 4    1    0    4      3    1      5   1    16

# %%
df_2['Comunidad Autónoma']
# Out:
# 0                ANDALUCÍA
# 1                   ARAGÓN
# 2      C. FORAL DE NAVARRA
# 3                 CANARIAS
# 4                CANTABRIA
# 5          CASTILLA Y LEÓN
# 6       CASTILLA-LA MANCHA
# 7                 CATALUÑA
# 8                    CEUTA
# 9     COMUNIDAD VALENCIANA
# 10             EXTREMADURA
# 11                 GALICIA
# 12           ILLES BALEARS
# 13                LA RIOJA
# 14                  MADRID
# 15                 MELILLA
# 16              PAÍS VASCO
# 17       PPDO. DE ASTURIAS
# 18        REGIÓN DE MURCIA
# Name: Comunidad Autónoma, dtype: object

# %%
df_2.corr()
# Out:
#                             Número de camas instaladas       TAC        RM  \
# Número de camas instaladas                    1.000000  0.935772  0.920254
# TAC                                           0.935772  1.000000  0.918942
# RM                                            0.920254  0.918942  1.000000
# GAM                                           0.848937  0.950844  0.885020
# HEM                                           0.781856  0.905101  0.861068
# ASD                                           0.936295  0.953296  0.970762
# LIT                                           0.858779  0.930416  0.946348
# BCO                                           0.365848  0.398390  0.666741
# ALI                                           0.903052  0.942079  0.972791
# SPECT                                         0.884174  0.840603  0.957978
# PET                                           0.855682  0.846283  0.961173
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_2.corr(),
           vmin = -1,
           vmax = 1,
           annot = True,
           square = True,
           linewidth = .5,
           cmap=sns.diverging_palette(150, 277, s=100, l=30, n=23));

# %%
plt.figure(figsize=(15,15))
sns.jointplot(data = df_2,
             x = 'Número de camas instaladas',
             y = 'TAC');

# %%
plt.figure(figsize=(15,15))
sns.lmplot(data = df_2,
          x = 'Número de camas instaladas',
          y = 'MAMOS');

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
sns.lmplot(data = df_2,
          x = 'Número de camas instaladas',
          y = 'TAC');

# %% [markdown]
# ## Nuevos datos
#
# [url_gasto_sanidad](https://www.mscbs.gob.es/estadEstudios/estadisticas/inforRecopilaciones/docs/presupuestosIniciales.pdf)
#
# [url_población](https://es.wikipedia.org/wiki/Anexo:Comunidades_y_ciudades_aut%C3%B3nomas_de_Espa%C3%B1a)

# %%
df_2['Comunidad Autónoma'].to_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2fdb126d7cd9> in <module>
# ----> 1 df_2['Comunidad Autónoma'].to_list()
#
# NameError: name 'df_2' is not defined

# %%
g_s_ccaa = pd.read_csv('./data/gasto_sanidad_CCAA.csv', sep=';')
g_s_ccaa.head()
# Out:
#   Comunidad Autónoma  Gasto_sanidad_2021(miles_euros)
# 0          ANDALUCÍA                         11759292
# 1             ARAGÓN                          2328735
# 2  PPDO. DE ASTURIAS                          1968939
# 3          CANTABRIA                           996633
# 4              CEUTA                             7566

# %%
gasto_comunidad = df_2.merge(g_s_ccaa, on='Comunidad Autónoma', how='inner')
gasto_comunidad
# Out:
#       Comunidad Autónoma  Número de camas instaladas  TAC   RM  GAM  HEM  ASD  \
# 0              ANDALUCÍA                       21350  143   77   31   53   44
# 1                 ARAGÓN                        5290   24   23    1    8    7
# 2    C. FORAL DE NAVARRA                        2331   15   10    0    3    2
# 3               CANARIAS                        6828   38   32   13   14   17
# 4              CANTABRIA                        1682    9    6    0    2    4
# 5        CASTILLA Y LEÓN                        9130   47   31    9    9    8
# 6     CASTILLA-LA MANCHA                        5899   39   24    3    8    4
# 7               CATALUÑA                       34322  122  106   19   36   52
# 8                  CEUTA                         252    1    1    0    0    0
# 9   COMUNIDAD VALENCIANA                       13811   91   68   17   66   38
# 10           EXTREMADURA                        4323   29   14    1    5    5
# ...

# %%
gasto_comunidad.corr()
# Out:
#                                  Número de camas instaladas       TAC  \
# Número de camas instaladas                         1.000000  0.935772
# TAC                                                0.935772  1.000000
# RM                                                 0.920254  0.918942
# GAM                                                0.848937  0.950844
# HEM                                                0.781856  0.905101
# ASD                                                0.936295  0.953296
# LIT                                                0.858779  0.930416
# BCO                                                0.365848  0.398390
# ALI                                                0.903052  0.942079
# SPECT                                              0.884174  0.840603
# PET                                                0.855682  0.846283
# MAMOS                                              0.973614  0.976776
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(gasto_comunidad.corr(),
           vmin = -1,
           vmax = 1,
           annot = True,
           square = True,
           linewidth = .5,
           cmap=sns.diverging_palette(150, 277, s=100, l=30, n=23));

# %%
poblacion_ccaa = pd.read_csv('./data/poblacion_CCAA.csv', sep=';')
poblacion_ccaa.head()
# Out:
#   Comunidad Autónoma  Población  Superficie
# 0          ANDALUCÍA    8464411       87599
# 1             ARAGÓN    1329391       47720
# 2  PPDO. DE ASTURIAS    1018784       10604
# 3          CANTABRIA     582905        5321
# 4              CEUTA      84202          20

# %%
poblacion_ccaa['Densidad_poblacion'] = poblacion_ccaa['Población'] / poblacion_ccaa['Superficie']
poblacion_ccaa
# Out:
#       Comunidad Autónoma  Población  Superficie  Densidad_poblacion
# 0              ANDALUCÍA    8464411       87599           96.626799
# 1                 ARAGÓN    1329391       47720           27.858152
# 2      PPDO. DE ASTURIAS    1018784       10604           96.075443
# 3              CANTABRIA     582905        5321          109.548017
# 4                  CEUTA      84202          20         4210.100000
# 5        CASTILLA Y LEÓN    2394918       94224           25.417282
# 6     CASTILLA-LA MANCHA    2045221       79461           25.738677
# 7               CANARIAS    2175952        7447          292.191755
# 8               CATALUÑA    7780479       32113          242.284402
# 9            EXTREMADURA    1063987       41634           25.555724
# 10               GALICIA    2701819       29575           91.354827
# 11         ILLES BALEARS    1171543        4992          234.684095
# 12      REGIÓN DE MURCIA    1511251       11314          133.573537
# ...

# %%
df_pob_ccaa = df.merge(poblacion_ccaa, on='Comunidad Autónoma', how='inner')
df_pob_ccaa.head()
# Out:
#    Código CCN  Código CNH                                Nombre  \
# 0   104000314       40059               HOSPITAL VIRGEN DEL MAR
# 1   104000316       40010  HOSPITAL UNIVERSITARIO TORRECARDENAS
# 2   104000319       40031  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA
# 3   104000320       40084                HOSPITAL LA INMACULADA
# 4   104000321       40118                  HOSPITAL DE PONIENTE
#
#   Comunidad Autónoma Provincia      Municipio                       Dirección  \
# 0          ANDALUCÍA   ALMERÍA        Almería   CARRETERA DEL MAMI, KM. 1 S/N
# 1          ANDALUCÍA   ALMERÍA        Almería  CALLE PARAJE TORRECARDENAS S/N
# 2          ANDALUCÍA   ALMERÍA        Almería          CARRETERA DE RONDA S/N
# 3          ANDALUCÍA   ALMERÍA  Huércal-Overa   AVENIDA DOCTORA ANA PARRA S/N
# 4          ANDALUCÍA   ALMERÍA      Ejido, El         CARRETERA ALMERIMAR S/N
#
#    Código Postal   Teléfono  Número de camas instaladas        Tipo de Centro  \
# ...

# %%
df_estudiantes = df_pob_ccaa[['Nombre','Comunidad Autónoma', 'Acreditación Docente', 'Población', 'Superficie', 'Densidad_poblacion']]
df_estudiantes.head()
# Out:
#                                  Nombre Comunidad Autónoma  \
# 0               HOSPITAL VIRGEN DEL MAR          ANDALUCÍA
# 1  HOSPITAL UNIVERSITARIO TORRECARDENAS          ANDALUCÍA
# 2  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA          ANDALUCÍA
# 3                HOSPITAL LA INMACULADA          ANDALUCÍA
# 4                  HOSPITAL DE PONIENTE          ANDALUCÍA
#
#   Acreditación Docente  Población  Superficie  Densidad_poblacion
# 0                   NO    8464411       87599           96.626799
# 1                   NO    8464411       87599           96.626799
# 2                   NO    8464411       87599           96.626799
# 3                   SI    8464411       87599           96.626799
# 4                   SI    8464411       87599           96.626799

# %%
mapa_centros_estudios = df_estudiantes[df_estudiantes['Acreditación Docente'] == 'SI']
mapa_centros_estudios
# Out:
#                                              Nombre Comunidad Autónoma  \
# 3                            HOSPITAL LA INMACULADA          ANDALUCÍA
# 4                              HOSPITAL DE PONIENTE          ANDALUCÍA
# 6                HOSPITAL DE ALTA RESOLUCION ELTOYO          ANDALUCÍA
# 11                         HOSPITAL PUNTA DE EUROPA          ANDALUCÍA
# 13   HOSPITAL UNIVERSITARIO DE JEREZ DE LA FRONTERA          ANDALUCÍA
# ..                                              ...                ...
# 806                   HOSPITAL UNIVERSITARIO CRUCES         PAÍS VASCO
# 807                               HOSPITAL SAN ELOY         PAÍS VASCO
# 808                      HOSPITAL GALDAKAO-USANSOLO         PAÍS VASCO
# 829                 HOSPITAL UNIVERSITARIO DE CEUTA              CEUTA
# 830                    HOSPITAL COMARCAL DE MELILLA            MELILLA
#
#     Acreditación Docente  Población  Superficie  Densidad_poblacion
# ...

# %% [markdown]
# ## Dataset sobre defunciones

# %%
import pandas as pd

# Importamos los datos
df = pd.read_csv('./data/defunciones_CCAA_tipo.csv', sep=';')

#Escogemos los casos por CCAA
df = df[(df['Comunidades y Ciudades Autónomas'] != 'Nacional') & (df['Comunidades y Ciudades Autónomas'] != 'Extranjero')]
ccaa = df['Comunidades y Ciudades Autónomas']

#Limpiamos los nombres de las CCAA
ccaa = ccaa.replace('\d', '', regex=True)
ccaa = ccaa.replace('\s', '', regex=True)

#Reinsertamos los datos limpios
df['Comunidades y Ciudades Autónomas'] = ccaa
df.head()
# Out:
#                       Causa de muerte   Sexo Comunidades y Ciudades Autónomas  \
# 680  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 681  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 682  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 683  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 684  001-102  I-XXII.Todas las causas  Total                        Andalucía
#
#                  Edad  Periodo   Total
# 680  Todas las edades     2019  70.505
# 681  Todas las edades     2018  72.806
# 682  Todas las edades     2017  71.234
# 683  Todas las edades     2016  69.231
# 684  Todas las edades     2015  72.001

# %%
df['Causa de muerte'].unique()
causas = df['Causa de muerte']
causas
# Out:
# 680                001-102  I-XXII.Todas las causas
# 681                001-102  I-XXII.Todas las causas
# 682                001-102  I-XXII.Todas las causas
# 683                001-102  I-XXII.Todas las causas
# 684                001-102  I-XXII.Todas las causas
#                             ...
# 770435    090-102  XX.Causas externas de mortalidad
# 770436    090-102  XX.Causas externas de mortalidad
# 770437    090-102  XX.Causas externas de mortalidad
# 770438    090-102  XX.Causas externas de mortalidad
# 770439    090-102  XX.Causas externas de mortalidad
# Name: Causa de muerte, Length: 697680, dtype: object

# %%
causas = causas.replace('\d', '', regex=True)
causas = causas.replace('-', '', regex=True)

causas = causas.str.extract('(\.[A-Za-z\s]+)', expand = False)
causas = causas.replace('\.','',regex=True)

causas
# Out:
# 680                    Todas las causas
# 681                    Todas las causas
# 682                    Todas las causas
# 683                    Todas las causas
# 684                    Todas las causas
#                       ...
# 770435    Causas externas de mortalidad
# 770436    Causas externas de mortalidad
# 770437    Causas externas de mortalidad
# 770438    Causas externas de mortalidad
# 770439    Causas externas de mortalidad
# Name: Causa de muerte, Length: 697680, dtype: object

# %%
df['Causa de muerte'] = causas
df = df[df['Causa de muerte'] != 'Todas las causas']
df = df.reset_index(drop=True)
df
# Out:
#                                 Causa de muerte     Sexo  \
# 0       Enfermedades infecciosas y parasitarias    Total
# 1       Enfermedades infecciosas y parasitarias    Total
# 2       Enfermedades infecciosas y parasitarias    Total
# 3       Enfermedades infecciosas y parasitarias    Total
# 4       Enfermedades infecciosas y parasitarias    Total
# ...                                         ...      ...
# 658915            Causas externas de mortalidad  Mujeres
# 658916            Causas externas de mortalidad  Mujeres
# 658917            Causas externas de mortalidad  Mujeres
# 658918            Causas externas de mortalidad  Mujeres
# 658919            Causas externas de mortalidad  Mujeres
#
#        Comunidades y Ciudades Autónomas              Edad  Periodo  Total
# 0                             Andalucía  Todas las edades     2019  1.130
# 1                             Andalucía  Todas las edades     2018  1.176
# ...

# %%
df.head()
# Out:
#                            Causa de muerte   Sexo  \
# 0  Enfermedades infecciosas y parasitarias  Total
# 1  Enfermedades infecciosas y parasitarias  Total
# 2  Enfermedades infecciosas y parasitarias  Total
# 3  Enfermedades infecciosas y parasitarias  Total
# 4  Enfermedades infecciosas y parasitarias  Total
#
#   Comunidades y Ciudades Autónomas              Edad  Periodo  Total
# 0                        Andalucía  Todas las edades     2019  1.130
# 1                        Andalucía  Todas las edades     2018  1.176
# 2                        Andalucía  Todas las edades     2017  1.245
# 3                        Andalucía  Todas las edades     2016  1.288
# 4                        Andalucía  Todas las edades     2015  1.450

# %%
df['Comunidades y Ciudades Autónomas'].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias,Principadode', 'Balears,Illes',
#        'Canarias', 'Cantabria', 'CastillayLeón', 'Castilla-LaMancha',
#        'Cataluña', 'ComunitatValenciana', 'Extremadura', 'Galicia',
#        'Madrid,Comunidadde', 'Murcia,Regiónde',
#        'Navarra,ComunidadForalde', 'PaísVasco', 'Rioja,La', 'Ceuta',
#        'Melilla'], dtype=object)
