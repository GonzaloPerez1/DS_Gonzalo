# %% [markdown]
# # Análisis Exploratorio de Datos
#
# ## Datasets:
# - dataset 1: Catálogo de hospitales en España.
# - dataset 2: Equipo médico por comunidad autónoma.
# - dataset 3: Gasto en sanidad por comunidad autónoma.
# - dataset 4: población y superficie de cada CCAA.
#
# ## Máquinas médicas:
# - **TAC**:Tomografía Axial Computerizada
# - **RM**: Resonancia Magnética
# - **GAM**: Gammacámara
# - **HEM**: Sala de Hemodinámica
# - **ASD**: Angiografía por Sustracción Digital
# - **LIT**: Litotricia Extracorporea por Ondas de Choque
# - **BCO**: Bomba de Cobalto
# - **ALI**: Acelerador de Partículas
# - **SPECT**: Tomografía por emisión de fotones
# - **PET**: Tomografía por emisión de positrones
# - **MAMOS**: Mamógrafo
# - **DO**: Densitómetros Óseos
# - **DIAL**: Equipos de Hemodiálisis
# - Cataluña: Los datos de gammacámara incluyen SPECT
#
# ## Páginas importantes:
# Las páginas incluidas a continuación son las fuentes de información necesarias en la creación de los datasets 3 y 4.
#
# - [url_datos_hospitales](https://www.mscbs.gob.es/ciudadanos/centrosCA.do)
# - [url_gasto_sanidad](https://www.mscbs.gob.es/estadEstudios/estadisticas/inforRecopilaciones/docs/presupuestosIniciales.pdf)
# - [url_población](https://es.wikipedia.org/wiki/Anexo:Comunidades_y_ciudades_aut%C3%B3nomas_de_Espa%C3%B1a)

# %% [markdown]
# ## 1. Importamos las librerias necesarias

# %%
import folium
import geocoder
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from folium import plugins

# %% [markdown]
# ## 2. Cargamos los datos y creamos los datasets finales

# %%
catalogo_hospitales = pd.read_csv('./data/Catalogo_de_Hospitales.csv')
catalogo_hospitales.head()
# Out:
#    Código CCN  Código CNH                                Nombre  \
# 0   104000314       40059               HOSPITAL VIRGEN DEL MAR
# 1   104000316       40010  HOSPITAL UNIVERSITARIO TORRECARDENAS
# 2   104000319       40031  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA
# 3   104000320       40084                HOSPITAL LA INMACULADA
# 4   104000321       40118                  HOSPITAL DE PONIENTE
#
#   Comunidad Autónoma Provincia      Municipio                       Dirección  \
# 0          ANDALUCÍA   ALMERÍA        Almería   CARRETERA DEL MAMI, KM. 1 S/N
# 1          ANDALUCÍA   ALMERÍA        Almería  CALLE PARAJE TORRECARDENAS S/N
# 2          ANDALUCÍA   ALMERÍA        Almería          CARRETERA DE RONDA S/N
# 3          ANDALUCÍA   ALMERÍA  Huércal-Overa   AVENIDA DOCTORA ANA PARRA S/N
# 4          ANDALUCÍA   ALMERÍA      Ejido, El         CARRETERA ALMERIMAR S/N
#
#    Código Postal   Teléfono  Número de camas instaladas        Tipo de Centro  \
# 0           4120  950210100                          76  Hospitales Generales
# 1           4009  950016114                         635  Hospitales Generales
# 2           4009  950017400                          69  Hospitales Generales
# 3           4600  950029176                         184  Hospitales Generales
# 4           4700  950022500                         261  Hospitales Generales
#
#                                Dependencia Funcional  Observaciones  \
# 0                                           PRIVADOS            NaN
# 1  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 2  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 3  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 4  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
#
#            Concierto Acreditación Docente
# 0  Concierto parcial                   NO
# 1     Sin concierto.                   NO
# 2     Sin concierto.                   NO
# 3      Sin concierto                   SI
# 4      Sin concierto                   SI

# %%
equipo_medico = pd.read_csv('./data/Equipo_Médico.csv', sep='\t')
equipo_medico.head()
# Out:
#   Comunidad Autónoma  TAC  RM  GAM  HEM  ASD  LIT  BCO  ALI  SPECT  PET  \
# 0          ANDALUCÍA  143  77   31   53   44   15    0   37     12    8
# 1             ARAGÓN   24  23    1    8    7    3    0    6      4    2
# 2  PPDO. DE ASTURIAS   19  17    4    4    4    3    0    8      4    3
# 3      ILLES BALEARS   23  25    5    9    7    4    0    4      3    2
# 4           CANARIAS   38  32   13   14   17    7    0   14     13    3
#
#    MAMOS  DO  DIAL
# 0     91  38   689
# 1     23   4   231
# 2     19   7   168
# 3     23  12   191
# 4     30  15   332

# %%
gasto_sanidad = pd.read_csv('./data/gasto_sanidad_CCAA.csv', sep=';')
gasto_sanidad.head()
# Out:
#   Comunidad Autónoma  Gasto_sanidad_2021(miles_euros)
# 0          ANDALUCÍA                         11759292
# 1             ARAGÓN                          2328735
# 2  PPDO. DE ASTURIAS                          1968939
# 3          CANTABRIA                           996633
# 4              CEUTA                             7566

# %%
poblacion_ccaa = pd.read_csv('./data/poblacion_CCAA.csv', sep=';')
poblacion_ccaa.head()
# Out:
#   Comunidad Autónoma  Población  Superficie
# 0          ANDALUCÍA    8464411       87599
# 1             ARAGÓN    1329391       47720
# 2  PPDO. DE ASTURIAS    1018784       10604
# 3          CANTABRIA     582905        5321
# 4              CEUTA      84202          20

# %%
defunciones_tipo_ccaa = pd.read_csv('./data/defunciones_CCAA_tipo.csv', sep=';')
defunciones_tipo_ccaa.head()
# Out:
#                     Causa de muerte   Sexo Comunidades y Ciudades Autónomas  \
# 0  001-102  I-XXII.Todas las causas  Total                         Nacional
# 1  001-102  I-XXII.Todas las causas  Total                         Nacional
# 2  001-102  I-XXII.Todas las causas  Total                         Nacional
# 3  001-102  I-XXII.Todas las causas  Total                         Nacional
# 4  001-102  I-XXII.Todas las causas  Total                         Nacional
#
#                Edad  Periodo    Total
# 0  Todas las edades     2019  418.703
# 1  Todas las edades     2018  427.721
# 2  Todas las edades     2017  424.523
# 3  Todas las edades     2016  410.611
# 4  Todas las edades     2015  422.568

# %% [markdown]
# ## 3. Creamos tablas y variables nuevas para poder realizar los gráficos

# %% [markdown]
# ### Dataframe con los 11 hospitales con mayor número de camas en España.
#
# - Posibles gráficos:
#     - Lollipop
#     - Mapa buscando con geocoder los nombres de los hospitales

# %%
data = catalogo_hospitales.groupby('Nombre')['Número de camas instaladas'].sum()
data = pd.DataFrame(data)
hospitales_con_mas_camas = data.sort_values(by='Número de camas instaladas', ascending= False)
hospitales_con_mas_camas = hospitales_con_mas_camas[:11]
hospitales_con_mas_camas
# Out:
#                                                     Número de camas instaladas
# Nombre
# COMPLEXO HOSPITALARIO UNIVERSITARIO DE SANTIAGO                           1395
# COMPLEXO HOSPITALARIO UNIVERSITARIO A CORUÑA                              1341
# HOSPITAL UNIVERSITARI VALL D'HEBRON                                       1315
# COMPLEXO HOSPITALARIO UNIVERSITARIO DE VIGO                               1273
# HOSPITAL GENERAL UNIVERSITARIO GREGORIO MARAÑON                           1253
# HOSPITAL UNIVERSITARIO MIGUEL SERVET                                      1213
# HOSPITAL UNIVERSITARIO 12 DE OCTUBRE                                      1196
# COMPLEJO HOSPITALARIO DE NAVARRA                                          1077
# PARC SANITARI SANT JOAN DE DEU - RECINTE SANT BOI.                        1065
# HOSPITAL UNIVERSITARIO LA PAZ                                             1052
# HOSPITAL UNIVERSITARIO DONOSTIA                                           1034

# %% [markdown]
# ### Dataframe con la cantidad de máquinas, número de camas y gasto sanitario por comunidad autónoma.

# %%
camas_por_ccaa = pd.DataFrame(catalogo_hospitales.groupby('Comunidad Autónoma')['Número de camas instaladas'].sum())
camas_y_maquinas = camas_por_ccaa.merge(equipo_medico, on='Comunidad Autónoma', how='inner')
camas_y_maquinas.head()
# Out:
#     Comunidad Autónoma  Número de camas instaladas  TAC  RM  GAM  HEM  ASD  \
# 0            ANDALUCÍA                       21350  143  77   31   53   44
# 1               ARAGÓN                        5290   24  23    1    8    7
# 2  C. FORAL DE NAVARRA                        2331   15  10    0    3    2
# 3             CANARIAS                        6828   38  32   13   14   17
# 4            CANTABRIA                        1682    9   6    0    2    4
#
#    LIT  BCO  ALI  SPECT  PET  MAMOS  DO  DIAL
# 0   15    0   37     12    8     91  38   689
# 1    3    0    6      4    2     23   4   231
# 2    2    0    6      4    2      8   3   111
# 3    7    0   14     13    3     30  15   332
# 4    1    0    4      3    1      5   1    16

# %%
camas_maquinas_gasto = camas_y_maquinas.merge(gasto_sanidad, on='Comunidad Autónoma', how='inner')
camas_maquinas_gasto
# Out:
#       Comunidad Autónoma  Número de camas instaladas  TAC   RM  GAM  HEM  ASD  \
# 0              ANDALUCÍA                       21350  143   77   31   53   44
# 1                 ARAGÓN                        5290   24   23    1    8    7
# 2    C. FORAL DE NAVARRA                        2331   15   10    0    3    2
# 3               CANARIAS                        6828   38   32   13   14   17
# 4              CANTABRIA                        1682    9    6    0    2    4
# 5        CASTILLA Y LEÓN                        9130   47   31    9    9    8
# 6     CASTILLA-LA MANCHA                        5899   39   24    3    8    4
# 7               CATALUÑA                       34322  122  106   19   36   52
# 8                  CEUTA                         252    1    1    0    0    0
# 9   COMUNIDAD VALENCIANA                       13811   91   68   17   66   38
# 10           EXTREMADURA                        4323   29   14    1    5    5
# 11               GALICIA                        9767   52   37    6   15   19
# 12         ILLES BALEARS                        3976   23   25    5    9    7
# 13              LA RIOJA                        1050    5    4    1    1    2
# 14                MADRID                       21700  114  136   25   52   55
# 15               MELILLA                         170    1    0    0    0    0
# 16            PAÍS VASCO                        7975   40   31    8   13   15
# 17     PPDO. DE ASTURIAS                        3930   19   17    4    4    4
# 18      REGIÓN DE MURCIA                        4862   29   23    2    7   12
#
#     LIT  BCO  ALI  SPECT  PET  MAMOS  DO  DIAL  \
# 0    15    0   37     12    8     91  38   689
# 1     3    0    6      4    2     23   4   231
# 2     2    0    6      4    2      8   3   111
# 3     7    0   14     13    3     30  15   332
# 4     1    0    4      3    1      5   1    16
# 5     4    0   13      6    1     41  14   304
# 6     3    0    4      4    1     26  10   111
# 7    12    0   36     24   14    105  45   716
# 8     0    0    0      0    0      1   1     0
# 9    11    0   26     13   12     57  38   566
# 10    1    0    6      4    1     19   3   100
# 11    4    0   15     12    4     35  16   448
# 12    4    0    4      3    2     23  12   191
# 13    1    0    2      1    1      4   3    38
# 14   18    3   50     29   19     96  47   726
# 15    0    0    0      0    0      1   0    15
# 16    8    0   16      7    6     30  10   182
# 17    3    0    8      4    3     19   7   168
# 18    2    0    5      5    2     21   8   112
#
#     Gasto_sanidad_2021(miles_euros)
# 0                          11759292
# 1                           2328735
# 2                           1253822
# 3                           3308761
# 4                            996633
# 5                           4376339
# 6                           3715937
# 7                           9789049
# 8                              7566
# 9                           7530056
# 10                          1905926
# 11                          4587712
# 12                          1935433
# 13                           552416
# 14                          8187538
# 15                             1171
# 16                          4219379
# 17                          1968939
# 18                          2187455

# %% [markdown]
# ### Dataframe con el número de centros con acreditación académica (universitarios), nombre de los hospitales, población, superficie y densidad de población por comunidad autónoma.
#
# Pasos a seguir:
# 1. Calcular la densidad de población (dataframe: poblacion_ccaa)
# 2. Juntar las tablas de 'catalogo_hospitales' y 'poblacion_ccaa'
# 3. Seleccionar las columnas necesarias ('Nombre','Comunidad Autónoma', 'Acreditación Docente', 'Población', 'Superficie', 'Densidad_poblacion')
# 4. Seleccionar sólo los centros que tienen acreditación académica

# %%
#1. Densidad de población
poblacion_ccaa['Densidad_poblacion'] = poblacion_ccaa['Población'] / poblacion_ccaa['Superficie']
poblacion_ccaa.head()
# Out:
#   Comunidad Autónoma  Población  Superficie  Densidad_poblacion
# 0          ANDALUCÍA    8464411       87599           96.626799
# 1             ARAGÓN    1329391       47720           27.858152
# 2  PPDO. DE ASTURIAS    1018784       10604           96.075443
# 3          CANTABRIA     582905        5321          109.548017
# 4              CEUTA      84202          20         4210.100000

# %%
#2. Merge de tablas
hospitales_poblacion_ccaa = catalogo_hospitales.merge(poblacion_ccaa, on='Comunidad Autónoma', how='inner')
hospitales_poblacion_ccaa.head()
# Out:
#    Código CCN  Código CNH                                Nombre  \
# 0   104000314       40059               HOSPITAL VIRGEN DEL MAR
# 1   104000316       40010  HOSPITAL UNIVERSITARIO TORRECARDENAS
# 2   104000319       40031  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA
# 3   104000320       40084                HOSPITAL LA INMACULADA
# 4   104000321       40118                  HOSPITAL DE PONIENTE
#
#   Comunidad Autónoma Provincia      Municipio                       Dirección  \
# 0          ANDALUCÍA   ALMERÍA        Almería   CARRETERA DEL MAMI, KM. 1 S/N
# 1          ANDALUCÍA   ALMERÍA        Almería  CALLE PARAJE TORRECARDENAS S/N
# 2          ANDALUCÍA   ALMERÍA        Almería          CARRETERA DE RONDA S/N
# 3          ANDALUCÍA   ALMERÍA  Huércal-Overa   AVENIDA DOCTORA ANA PARRA S/N
# 4          ANDALUCÍA   ALMERÍA      Ejido, El         CARRETERA ALMERIMAR S/N
#
#    Código Postal   Teléfono  Número de camas instaladas        Tipo de Centro  \
# 0           4120  950210100                          76  Hospitales Generales
# 1           4009  950016114                         635  Hospitales Generales
# 2           4009  950017400                          69  Hospitales Generales
# 3           4600  950029176                         184  Hospitales Generales
# 4           4700  950022500                         261  Hospitales Generales
#
#                                Dependencia Funcional  Observaciones  \
# 0                                           PRIVADOS            NaN
# 1  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 2  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 3  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
# 4  SERVICIOS E INSTITUTOS DE SALUD DE LAS COMUNID...            NaN
#
#            Concierto Acreditación Docente  Población  Superficie  \
# 0  Concierto parcial                   NO    8464411       87599
# 1     Sin concierto.                   NO    8464411       87599
# 2     Sin concierto.                   NO    8464411       87599
# 3      Sin concierto                   SI    8464411       87599
# 4      Sin concierto                   SI    8464411       87599
#
#    Densidad_poblacion
# 0           96.626799
# 1           96.626799
# 2           96.626799
# 3           96.626799
# 4           96.626799

# %%
#3. Selección de las columnas necesarias
df_estudiantes = hospitales_poblacion_ccaa[['Nombre',
                                            'Comunidad Autónoma', 
                                            'Acreditación Docente', 
                                            'Población', 
                                            'Superficie', 
                                            'Densidad_poblacion']]
df_estudiantes.head()
# Out:
#                                  Nombre Comunidad Autónoma  \
# 0               HOSPITAL VIRGEN DEL MAR          ANDALUCÍA
# 1  HOSPITAL UNIVERSITARIO TORRECARDENAS          ANDALUCÍA
# 2  HOSPITAL DE  LA CRUZ ROJA DE ALMERIA          ANDALUCÍA
# 3                HOSPITAL LA INMACULADA          ANDALUCÍA
# 4                  HOSPITAL DE PONIENTE          ANDALUCÍA
#
#   Acreditación Docente  Población  Superficie  Densidad_poblacion
# 0                   NO    8464411       87599           96.626799
# 1                   NO    8464411       87599           96.626799
# 2                   NO    8464411       87599           96.626799
# 3                   SI    8464411       87599           96.626799
# 4                   SI    8464411       87599           96.626799

# %%
#4. Selección de centros con acreditación académica
mapa_centros_estudios = df_estudiantes[df_estudiantes['Acreditación Docente'] == 'SI']
mapa_centros_estudios
# Out:
#                                              Nombre Comunidad Autónoma  \
# 3                            HOSPITAL LA INMACULADA          ANDALUCÍA
# 4                              HOSPITAL DE PONIENTE          ANDALUCÍA
# 6                HOSPITAL DE ALTA RESOLUCION ELTOYO          ANDALUCÍA
# 11                         HOSPITAL PUNTA DE EUROPA          ANDALUCÍA
# 13   HOSPITAL UNIVERSITARIO DE JEREZ DE LA FRONTERA          ANDALUCÍA
# ..                                              ...                ...
# 806                   HOSPITAL UNIVERSITARIO CRUCES         PAÍS VASCO
# 807                               HOSPITAL SAN ELOY         PAÍS VASCO
# 808                      HOSPITAL GALDAKAO-USANSOLO         PAÍS VASCO
# 829                 HOSPITAL UNIVERSITARIO DE CEUTA              CEUTA
# 830                    HOSPITAL COMARCAL DE MELILLA            MELILLA
#
#     Acreditación Docente  Población  Superficie  Densidad_poblacion
# 3                     SI    8464411       87599           96.626799
# 4                     SI    8464411       87599           96.626799
# 6                     SI    8464411       87599           96.626799
# 11                    SI    8464411       87599           96.626799
# 13                    SI    8464411       87599           96.626799
# ..                   ...        ...         ...                 ...
# 806                   SI    2220504        7234          306.953829
# 807                   SI    2220504        7234          306.953829
# 808                   SI    2220504        7234          306.953829
# 829                   SI      84202          20         4210.100000
# 830                   SI      87076          12         7256.333333
#
# [245 rows x 6 columns]

# %% [markdown]
# ### Limpieza de datos del dataframe 'defunciones_tipo_ccaa'
#
# Pasos:
# 1. Escoger los datos de las CCAA
# 2. Eliminar los números en los nombres de las CCAA
# 3. Limpiar la columnas de 'causa muerte'
# 4. Escoger las causas de muertes únicas

# %%
#1. Escoger los datos de las CCAA
mask1 = defunciones_tipo_ccaa['Comunidades y Ciudades Autónomas'] != 'Nacional'
mask2 = defunciones_tipo_ccaa['Comunidades y Ciudades Autónomas'] != 'Extranjero'

defunciones_tipo_ccaa = defunciones_tipo_ccaa[(mask1) & (mask2)]
defunciones_tipo_ccaa.head()
# Out:
#                       Causa de muerte   Sexo Comunidades y Ciudades Autónomas  \
# 680  001-102  I-XXII.Todas las causas  Total                     01 Andalucía
# 681  001-102  I-XXII.Todas las causas  Total                     01 Andalucía
# 682  001-102  I-XXII.Todas las causas  Total                     01 Andalucía
# 683  001-102  I-XXII.Todas las causas  Total                     01 Andalucía
# 684  001-102  I-XXII.Todas las causas  Total                     01 Andalucía
#
#                  Edad  Periodo   Total
# 680  Todas las edades     2019  70.505
# 681  Todas las edades     2018  72.806
# 682  Todas las edades     2017  71.234
# 683  Todas las edades     2016  69.231
# 684  Todas las edades     2015  72.001

# %%
#2. Eliminar números de las CCAA
ccaa = defunciones_tipo_ccaa['Comunidades y Ciudades Autónomas']

ccaa = ccaa.replace('\d', '', regex=True)
ccaa = ccaa.replace('\s', '', regex=True)

defunciones_tipo_ccaa['Comunidades y Ciudades Autónomas'] = ccaa
defunciones_tipo_ccaa.head()
# Out:
#                       Causa de muerte   Sexo Comunidades y Ciudades Autónomas  \
# 680  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 681  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 682  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 683  001-102  I-XXII.Todas las causas  Total                        Andalucía
# 684  001-102  I-XXII.Todas las causas  Total                        Andalucía
#
#                  Edad  Periodo   Total
# 680  Todas las edades     2019  70.505
# 681  Todas las edades     2018  72.806
# 682  Todas las edades     2017  71.234
# 683  Todas las edades     2016  69.231
# 684  Todas las edades     2015  72.001

# %%
#3. Limpiar la columna 'causa muerte'
causas = defunciones_tipo_ccaa['Causa de muerte']

causas = causas.replace('\d', '', regex=True)
causas = causas.replace('-', '', regex=True)

causas = causas.str.extract('(\.[A-Za-z\s]+)', expand = False)
causas = causas.replace('\.','',regex=True)

defunciones_tipo_ccaa['Causa de muerte'] = causas
defunciones_tipo_ccaa.head()
# Out:
#       Causa de muerte   Sexo Comunidades y Ciudades Autónomas  \
# 680  Todas las causas  Total                        Andalucía
# 681  Todas las causas  Total                        Andalucía
# 682  Todas las causas  Total                        Andalucía
# 683  Todas las causas  Total                        Andalucía
# 684  Todas las causas  Total                        Andalucía
#
#                  Edad  Periodo   Total
# 680  Todas las edades     2019  70.505
# 681  Todas las edades     2018  72.806
# 682  Todas las edades     2017  71.234
# 683  Todas las edades     2016  69.231
# 684  Todas las edades     2015  72.001

# %%
#4. Elegir las causas de las muertes
defunciones_tipo_ccaa = defunciones_tipo_ccaa[defunciones_tipo_ccaa['Causa de muerte'] != 'Todas las causas']
defunciones_tipo_ccaa = defunciones_tipo_ccaa.reset_index(drop=True)
defunciones_tipo_ccaa.head()
# Out:
#                            Causa de muerte   Sexo  \
# 0  Enfermedades infecciosas y parasitarias  Total
# 1  Enfermedades infecciosas y parasitarias  Total
# 2  Enfermedades infecciosas y parasitarias  Total
# 3  Enfermedades infecciosas y parasitarias  Total
# 4  Enfermedades infecciosas y parasitarias  Total
#
#   Comunidades y Ciudades Autónomas              Edad  Periodo  Total
# 0                        Andalucía  Todas las edades     2019  1.130
# 1                        Andalucía  Todas las edades     2018  1.176
# 2                        Andalucía  Todas las edades     2017  1.245
# 3                        Andalucía  Todas las edades     2016  1.288
# 4                        Andalucía  Todas las edades     2015  1.450

# %% [markdown]
# ## 4. Gráficas

# %% [markdown]
# ### Correlación de los datos del dataset 'catalogo_hospitales'

# %%
plt.figure(figsize=(10,10))
sns.heatmap(catalogo_hospitales.corr(),
           vmin = -1,
           vmax = 1,
           annot = True,
           square = True,
           linewidth = .5,
           cmap=sns.diverging_palette(150, 277, s=100, l=30, n=13));

# %% [markdown]
# ### Gráfico de barras con número de camas por tipo de Dependencial Funcional (centros privados, públicos...)

# %%
plt.figure(figsize=(12,12)) #Cambiar
sns.histplot(data = catalogo_hospitales,
        x = 'Número de camas instaladas',
        multiple = 'stack',
        hue = 'Dependencia Funcional',
        palette='dark',
        edgecolor="0.1",
        linewidth=.7);

# %% [markdown]
# ### Gráfico Lollipop para visualizar las hospitales con mayor número de camas

# %%
plt.figure(figsize=(10,5))
plt.hlines(y=hospitales_con_mas_camas['Número de camas instaladas'].index,
           xmin=0,
           xmax=hospitales_con_mas_camas['Número de camas instaladas'],
           color='#A300F5')

plt.plot(hospitales_con_mas_camas['Número de camas instaladas'],
         hospitales_con_mas_camas['Número de camas instaladas'].index,
         "o",
         color='#A300F5')

plt.xlabel('Número de camas');

# %% [markdown]
# ### Mapa con los hospitales con mayor número de camas
#
# Pasos:
# 1. Buscamos las coordenadas de los distintos hospitales por nombre
# 2. Como podemos comprobar nos faltan algunos, esto se debe a que el nombre varia de los datos al mapa
# 3. Rellenamos los vacíos de la lista con los nombres correctos
# 4. Creamos el mapa con la lista ya completa

# %%
#1. Buscamos las coordenadas de los distintos hospitales por nombre

lista_sitios = []
for i in hospitales_con_mas_camas.index:
    g = geocoder.osm(i)
    lista_sitios.append(g.latlng)

# %%
#2. Como podemos comprobar nos faltan algunos, esto se debe a que el nombre varia de los datos al mapa

lista_sitios
# Out:
# [[42.86988465, -8.56585229973772],
#  [43.34426335, -8.38914622033265],
#  None,
#  None,
#  [40.419688449999995, -3.6711262290170836],
#  [41.63455725, -0.8997979456424298],
#  [40.376679499999995, -3.6988633268413382],
#  [42.805091399999995, -1.6685624933271659],
#  None,
#  [40.48144225, -3.6872531870474865],
#  None]

# %%
#3. Rellenamos los vacíos de la lista con los nombres correctos

lista_sitios[2] = geocoder.osm('HOSPITAL GENERAL VALL D\'HEBRON').latlng
lista_sitios[3] = geocoder.osm('HOSPITAL ÁLVARO CUNQUEIRO').latlng
lista_sitios[8] = geocoder.osm('PARC SANITARI SANT JOAN DE DÉU').latlng
lista_sitios[10] = geocoder.osm('DONOSTIA UNIBERTSITATE OSPITALEA').latlng

# %%
#4. Creamos el mapa con la lista ya completa

mapa_hospitales_mas_camas = folium.Map(location=[40, -2], zoom_start=6)

for i in range(len(lista_sitios)):
    folium.Marker(location=lista_sitios[i]).add_to(mapa_hospitales_mas_camas)
    
mapa_hospitales_mas_camas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f61e20547b2d486c8afb44896f1a26c4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f61e20547b2d486c8afb44896f1a26c4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f61e20547b2d486c8afb44896f1a26c4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f61e20547b2d486c8afb44896f1a26c4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.0%2C%20-2.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20cr ...

# %% [markdown]
# ### Gráfico con la correlación de los datos del dataset 'camas_maquinas_gasto'

# %%
plt.figure(figsize=(15,15)) #Sin interes
sns.heatmap(camas_maquinas_gasto.corr(),
           vmin = -1,
           vmax = 1,
           annot = True,
           square = True,
           linewidth = .5,
           cmap=sns.diverging_palette(150, 277, s=100, l=30, n=23));

# %% [markdown]
# ## 5. Teorias a demostrar
#
# 1. Cuanto más dinero tiene un hospital más máquinas puede comprar
# 2. Madrid es la CCAA con el mayor de número de hospitales que tienen una gran cantidad de camas
# 3. Extremadura es una de las CCAA con menos recursos de España
# 4. No hay suficientes hospitales universitarios para la gente que estudia medicina, enfermería, auxiliar...
#
# Las teorías se pueden variar según se vayan viendo los casos
