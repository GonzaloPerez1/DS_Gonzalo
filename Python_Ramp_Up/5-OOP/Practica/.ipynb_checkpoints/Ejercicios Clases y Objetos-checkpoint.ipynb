# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda():
    '''
    Somos una empresa con varias tiendas repartidas en dierentes puntos.
    Este programa se utilizará para poder llevar la contabilidad de todas ellas.
    '''
    #Atributos comunes
    tipo = "Electrodomésticos"
    abierta = True
    
    def __init__(self, nombre, direccion, empleados, venta_ult_3_mes):
        '''
        Atributos propios de cada tienda:
            Nombre de la tienda
            Dirección de la tienda
            Número de empleados por cada tienda
            Cúales son las ventas de los últimos 3 años
        '''
        self.name = nombre
        self.location = direccion
        self.employee = empleados
        self.sales = venta_ult_3_mes
        
    def ventas_mensuales(self):
        '''
        Ventas Mensuales por tienda:
            Antes de poder usar cualquier método habrá que crear nuestras tiendas
            con las características propias de cada una
            Ejemplo:
                tienda_vallecas = Tienda("vallecas", "Avd. Sierra Vieja, 15", 30, (1000, 1500, 960))
                tienda_vallecas.ventas_mensuales()
        '''
        print(sum(self.sales))
        
    def media_ventas(self):
        '''
        Media de las ventas de cada tienda:
            Ejemplo:
                tienda_vallecas.media_ventas()
        '''
        print(f"La media de ventas es de: {(sum(self.sales))/len(self.sales)}")
        
    def name_location(self):
        '''
        Output con el nombre y la dirección de la tienda.
        '''
        print("Nombre: " + self.name + ", Dirección: " + self.location)
    
    def ventas_ultimo_mes(self):
        '''
        Output con el valor de las ventas del último mes.
        '''
        print(f"Las ventas del último mes fueron de: {self.sales[-1]}")
        
    def proyeccion_ventas(self, x):
        if x < 1000:
            self.sales = (1.2 * sum(self.sales))
            print(f"Tu proyección es de: {self.sales}")
        if x >= 1000:
            self.sales = (1.5 * sum(self.sales))
            print(f"Tu proyección es de: {self.sales}")

# %%
tienda_vallecas = Tienda("Villa de Vallecas", "Avd. Sierra Vieja, 15", 30, (1000, 1500, 960))
tienda_el_pozo = Tienda("El Pozo", "Calle Cazorla", 13, (900, 1200, 875))
tienda_mejorada = Tienda("Mejorada del Campo", "Calle Santa Rosa", 60, (2000, 1700, 1900))

# Pruebas de la clase
tienda_vallecas.media_ventas()
tienda_vallecas.name_location()
tienda_vallecas.ventas_ultimo_mes()
tienda_vallecas.proyeccion_ventas(1000)


# Calcular las ventas del último mes de todas las tiendas
#for i in [tienda_vallecas, tienda_el_pozo, tienda_mejorada]:
#    print(i.ventas_ultimo_mes())
    
# Imprimir las direcciones que contengan avenida
print()

# Documentación
print(Tienda.__doc__)
print(Tienda.__init__.__doc__)
# Out:
# La media de ventas es de: 1153.3333333333333
# Nombre: Villa de Vallecas, Dirección: Avd. Sierra Vieja, 15
# Las ventas del último mes fueron de: 960
# Tu proyección es de: 5190.0
#
#
#     Somos una empresa con varias tiendas repartidas en dierentes puntos.
#     Este programa se utilizará para poder llevar la contabilidad de todas ellas.
#
#
#         Atributos propios de cada tienda:
#             Nombre de la tienda
#             Dirección de la tienda
#             Número de empleados por cada tienda
#             Cúales son las ventas de los últimos 3 años

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro():
    '''
    Clase perro
    '''
    # Características comunes
    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0
    
    def __init__(self, raza, color, propiedad):
        '''
        Características específicas del perro
        '''
        self.raza = raza
        self.color = color
        if not self.color:
            self.color = "Marrón"
        self.propiedad = propiedad
        
    def andar(self, aumento_velocidad):
        '''
        Método para que le perro ande
        '''
        velocidad = 0
        v = velocidad + aumento_velocidad
        print(f"La velocidad actual del perro es de: {v}") 
    
    def parar(self):
        '''
        Método para que el perro pare
        '''
        velocidad = 0
        print(f"El perro está parado, tiene una velocidad de: {velocidad}")
        
    def ladrar(self, x):
        '''
        Método para que el perro ladre
        '''
        print(f"GUAU! {x}")

# %%
Lasi = Perro("Bulldog", "Gris", False)
print(Lasi.patas)
print(Lasi.orejas)
print(Lasi.ojos)
print(Lasi.velocidad)
print(Lasi.raza)
print(Lasi.color)
print(Lasi.propiedad)
Lasi.andar(20)
Lasi.parar()
Lasi.ladrar("Piña")
# Out:
# 4
# 2
# 2
# 0
# Bulldog
# Gris
# False
# La velocidad actual del perro es de: 20
# El perro está parado, tiene una velocidad de: 0
# GUAU! Piña
